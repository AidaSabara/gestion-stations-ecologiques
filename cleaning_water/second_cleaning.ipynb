# %%
import pandas as pd
import numpy as np

# --- CHARGEMENT DU FICHIER ---
fichier_entree_initial = "UGB_Sanar_Station_Dataset_Clean.csv"
fichier_sortie_final_nettoye = "UGB_Sanar_Station_Final.csv"

# Lire le fichier CSV
df = pd.read_csv(fichier_entree_initial)

# --- ÉTAPE 1 : SUPPRESSION DES COLONNES PEU REMPLIES ---
taux_complétion = df.notnull().mean()
colonnes_a_supprimer = taux_complétion[taux_complétion < 0.60].index.tolist()
df = df.drop(columns=colonnes_a_supprimer)

# --- ÉTAPE 2 : SUPPRESSION DES COLONNES INUTILES OU BRUITÉES ---
colonnes_inutiles = [col for col in df.columns if "Unnamed" in col or "Commentaire" in col or "responsable" in col.lower()]
df = df.drop(columns=colonnes_inutiles)

# --- ÉTAPE 3 : NETTOYAGE DES NOMS DE COLONNES ---
df.columns = (
    df.columns
    .str.strip()
    .str.replace(r"[^\w\s]", "", regex=True)
    .str.replace(" ", "_")
    .str.lower()
)

# --- ÉTAPE 4 : SUPPRESSION DES LIGNES DOUBLONS ---
df = df.drop_duplicates()

# --- ÉTAPE 5 : CONVERSION DES DATES (si applicable) ---
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'], errors='coerce')

# --- ÉTAPE 6 : AFFICHAGE DES INFORMATIONS ---
print("Colonnes restantes :", df.columns.tolist())
print("\nAperçu des premières lignes :\n", df.head())
print("\nStatistiques descriptives :\n", df.describe(include='all'))

# --- ÉTAPE 7 : ENREGISTREMENT DU FICHIER NETTOYÉ ---
df.to_csv(fichier_sortie_final_nettoye, index=False)
print(f"\n✅ Fichier nettoyé enregistré sous : {fichier_sortie_final_nettoye}")
# Out:
# Colonnes restantes : ['id_station', 'phase', 'type_filtre', 'id_filtre', 'ph', 'potentiel_redox_mv', 'dbo5_mg_l', 'dco_mg_l', 'mes_mg_l', 'nitrates_mg_l', 'ammonium_mg_l', 'azote_total_mg_l', 'phosphates_mg_l', 'coliformes_fecaux_cfu_100ml', 'nom_feuille', 'contient_valeurs_estimees']
#
# Aperçu des premières lignes :
#        id_station   phase        type_filtre id_filtre    ph  \
# 0  Sanar_Station  Entree     Non_Applicable       FV1  7.28
# 1  Sanar_Station  Entree     Non_Applicable       FV2   NaN
# 2  Sanar_Station  Entree     Non_Applicable   General  7.56
# 3  Sanar_Station  Sortie  Filtre_Horizontal        FH  8.06
# 4  Sanar_Station  Sortie    Filtre_Vertical       FV1  7.84
#
#    potentiel_redox_mv   dbo5_mg_l  dco_mg_l    mes_mg_l  nitrates_mg_l  \
# 0                 NaN  361.000000     740.0  242.000000      18.070000
# 1                 NaN   71.266667     239.0   72.666667      66.666667
# 2                 NaN  575.000000     810.0  222.000000      20.330000
# 3                 NaN    3.400000      75.0   17.000000       6.320000
# 4                 NaN   70.300000     270.0   98.000000      11.300000
#
#    ammonium_mg_l  azote_total_mg_l  phosphates_mg_l  \
# 0      55.000000             110.0        69.600000
# 1     443.333333             230.0       338.333333
# 2      20.800000             100.0        43.000000
# 3       3.200000              40.0         2.000000
# 4      21.000000              90.0        46.000000
#
#    coliformes_fecaux_cfu_100ml nom_feuille  contient_valeurs_estimees
# 0                 2.670000e+06  Entree FV1                      False
# 1                 2.733333e+06  Entréé FV2                       True
# 2                 3.000000e+07    Entree 1                      False
# 3                 0.000000e+00        SFHa                      False
# 4                 3.670000e+06       SFV1a                      False
#
# Statistiques descriptives :
#             id_station   phase      type_filtre id_filtre          ph  \
# count             122     122              122       122  117.000000
# unique              1       2                3         4         NaN
# top     Sanar_Station  Sortie  Filtre_Vertical       FV1         NaN
# freq              122      84               61        50         NaN
# mean              NaN     NaN              NaN       NaN    5.907516
# std               NaN     NaN              NaN       NaN    3.033161
# min               NaN     NaN              NaN       NaN    0.000000
# 25%               NaN     NaN              NaN       NaN    5.530000
# 50%               NaN     NaN              NaN       NaN    7.530000
# 75%               NaN     NaN              NaN       NaN    8.020000
# max               NaN     NaN              NaN       NaN    8.380000
#
#         potentiel_redox_mv   dbo5_mg_l     dco_mg_l    mes_mg_l  \
# count           107.000000   91.000000    93.000000   93.000000
# unique                 NaN         NaN          NaN         NaN
# top                    NaN         NaN          NaN         NaN
# freq                   NaN         NaN          NaN         NaN
# mean            -12.416989  120.911883   312.711343   78.386319
# std             152.190175  202.258439   505.094154  137.091342
# min            -295.000000    0.000000     0.000000    0.000000
# 25%            -176.500000    2.020484    16.309506    6.000000
# 50%               5.000000   39.400000   136.000000   27.000000
# 75%             103.000000  109.008643   253.000000   70.500000
# max             278.000000  738.000000  2500.000000  778.000000
#
#         nitrates_mg_l  ammonium_mg_l  azote_total_mg_l  phosphates_mg_l  \
# count       93.000000      93.000000         93.000000        93.000000
# unique            NaN            NaN               NaN              NaN
# top               NaN            NaN               NaN              NaN
# freq              NaN            NaN               NaN              NaN
# mean        12.614835      30.194602        166.083763        32.987427
# std         12.934524      68.476204        249.066709        53.930018
# min          0.000000       0.000000          0.000000         0.000000
# 25%          4.000000       2.200000         21.338541         4.000000
# 50%          9.500000       5.200000         75.000000        16.100000
# 75%         17.170000      36.333333        158.333333        42.300000
# max         66.666667     443.333333       1200.000000       338.333333
#
#         coliformes_fecaux_cfu_100ml nom_feuille contient_valeurs_estimees
# count                  9.200000e+01         122                       122
# unique                          NaN          10                         2
# top                             NaN  Entree FV1                     False
# freq                            NaN          14                        88
# mean                   6.477307e+06         NaN                       NaN
# std                    1.982964e+07         NaN                       NaN
# min                    0.000000e+00         NaN                       NaN
# 25%                    4.000000e+00         NaN                       NaN
# 50%                    8.441989e+05         NaN                       NaN
# 75%                    3.208125e+06         NaN                       NaN
# max                    1.230000e+08         NaN                       NaN
#
# ✅ Fichier nettoyé enregistré sous : UGB_Sanar_Station_Final.csv
